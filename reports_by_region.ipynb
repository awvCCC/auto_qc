# %%
import os
import urllib
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
today = datetime.now().strftime('%Y-%m-%d')
yesterday = datetime.strftime(datetime.now() - timedelta(1), '%Y-%m-%d')

# %%
csv = (r'C:\Users\student\Documents\QAQC_reports\csv_vessel' + r'csv.csv')

# %%
def QAQC_datapull(a,b,c,d):
    if a == 'hourly':
        e = 'tmean,rh,vp,sr,ws,wind_vec,wind_std,pp,st5,st15,gust,gusttm,gustdir'
        r = pd.date_range(start=c,end=d,freq='H')
    elif a == 'five_minute':
        e = 'tmean,rh,vp,sr,ws,wind_vec,wind_std,pp,st5,st15,gust,gusttm,gustdir'
        r = pd.date_range(start=c,end=d,freq='5min')
    elif a == 'daily':
        e = 'tave,tmax,tmin,vp,rhmax,rhmin,sr,wrun,pp,st5mx,st5mn,st15mx,st15mn,gust,gustdir'
        r = pd.date_range(start=c,end=d,freq='D')
        
    urllib.request.urlretrieve('http://coagmet.colostate.edu/cgi-bin/web_services.pl?' +
                              'type=' + a +
                              '&sids=' + b +
                              '&sdate=' + c +
                              '&edate=' + d +
                              '&elems=' + e,
                              filename=csv)
    
    data = pd.read_csv(csv)
    
    data = data.reset_index()
    
    headers = e.split(',')
    
    headers.insert(0,'date')
    headers.insert(0,'station')
    
    data.columns = headers
    
    data['date'] = pd.to_datetime(data.date)
    
    if a == 'hourly':
        r = pd.date_range(start=c,end=d,freq='H')
    elif a == 'five_minute':
        r = pd.date_range(start=c,end=d,freq='5min')
    elif a == 'daily':
        r = pd.date_range(start=c,end=d,freq='D')
    
    data = data.set_index('date').reindex(r,copy=False).rename_axis('date')
    
    return data

# %%
def create_report(x):
    file = (x['path'] + r'\QAQC_report_' + x['drainage'] + 
            '_' + x['region'] + "_" + yesterday + '.txt')
    return file

# %%
Collegiate_Valley = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Arkansas_Drainage\Collegiate_Valley',
    'stations':'bnv01,sld01',
    'drainage':'Arkansas',
    'region':'Collegiate_Valley'
}
East_Valley_Bottom = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Arkansas_Drainage\East_Valley_Bottom',
    'stations':'hly01,hly02,lam01,lam03,lam04,mcl01',
    'drainage':'Arkansas',
    'region':'East_Valley_Bottom'
}
Mesas = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Arkansas_Drainage\Mesas',
    'stations':'cnn01,hne01,pnr01,wcf01',
    'drainage':'Arkansas',
    'region':'Mesas'
}
North_of_Valley = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Arkansas_Drainage\North_of_Valley',
    'stations':'scm01',
    'drainage':'Arkansas',
    'region':'Mesas'
}
Plateau_South_of_Valley = {
    'path': r'C:\Users\student\Documents\QAQC_reports\Arkansas_Drainage\Plateau_South_of_Valley',
    'stations':'wls01',
    'drainage':'Arkansas',
    'region':'Plateau_South_of_Valley'
}
West_Valley_Bottom = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Arkansas_Drainage\West_Valley_Bottom',
    'stations':'avn01,fwl01,ljt01,rfd01',
    'drainage':'Arkansas',
    'region':'West_Valley_Bottom'
}
Lower_Valley = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\Lower_Valley',
    'stations':'cbl01,slt01',
    'drainage':'Colorado',
    'region':'Lower_Valley'
}
Eagle_River_Valley = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\Eagle_River_Valley',
    'stations':'egl01,gyp01',
    'drainage':'Colorado',
    'region':'Eagle_River_Valley'
}
Four_Corners = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\Four_Corners',
    'stations':'ctz01,dvc01,mnc01,twc01,yjk01,yuc01',
    'drainage':'Colorado',
    'region':'Four_Corners'
}
Grand_Valley = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\Grand_Valley',
    'stations':'cbn01,frt03,orm02',
    'drainage':'Colorado',
    'region':'Grand_Valley'
}
Headwaters = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\Headwaters',
    'stations':'gby01,krm01,wfd01',
    'drainage':'Colorado',
    'region':'Headwaters'
}
Lower_Gunnison = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\Lower_Gunnison',
    'stations':'dlt01,ekt01,hot02,mtr01,oth01',
    'drainage':'Colorado',
    'region':'Lower_Gunnison'
}
San_Juan = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\San_Juan',
    'stations':'drg01,ign01,kln01,pgs01',
    'drainage':'Colorado',
    'region':'San Juan'
}
San_Miguel_Paradox = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\San_Miguel_Paradox',
    'stations':'brk01,nwd01',
    'drainage':'Colorado',
    'region': r'San_Miguel_Paradox'
}
Upper_Gunnison = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\Upper_Gunnison',
    'stations':'gun01',
    'drainage':'Colorado',
    'region':'Upper_Gunnison'
}
Yampa_White = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\Yampa_White',
    'stations':'clk01,hyd01,mkr01',
    'drainage':'Colorado',
    'region': 'Yampa_White'
}
North_Plains = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Kansas_Drainage\North_Plains',
    'stations':'akr02,hxt01,hyk02,ilf01,pai01,stg01,wry02,yum02',
    'drainage':'Kansas',
    'region':'North_Plains'
}
South_Plains = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Kansas_Drainage\South_Plains',
    'stations':'brl02,brl03,idl01,sbt01,stn01',
    'drainage':'Kansas',
    'region':'South_Plains'
}
Front_Range_Foothills = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Platte_Drainage\Front_Range_Foothills',
    'stations':'ckp01',
    'drainage':'Platte',
    'region':'Front_Range_Foothills'
}
Lower_Plains = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Platte_Drainage\Lower_Plains',
    'stations':'brg01,hxt01,ksy01,ksy02',
    'drainage':'Platte',
    'region':'Lower_Plains'
}
North_Front_Range = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Platte_Drainage\North_Front_Range',
    'stations':'alt01,fcc01,fcl01,ftc01,ftc03,gly04,lcn01',
    'drainage':'Platte',
    'region':'North_Front_Range'
}
North_Park = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Platte_Drainage\North_Park',
    'stations':'cow01,heb01,lar01',
    'drainage':'Platte',
    'region':'North_Park'
}
South_Front_Range = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Platte_Drainage\South_Front_Range',
    'stations':'ccr01,cht01,eac01,ftl01,lsl01,pkh01',
    'drainage':'Platte',
    'region':'South_Front_Range'
}
South_Park = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Platte_Drainage\South_Park',
    'stations':'bnv01,jfn01,sld01',
    'drainage':'Platte',
    'region':'South_Park'
}
San_Luis_Valley = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Rio_Grande_Drainage\San_Luis_Valley',
    'stations':'bla01,ctr01,ctr02,ljr01,san01',
    'drainage':'Rio_Grande',
    'region':'San_Luis_Valley'
}


region_list = [Collegiate_Valley,East_Valley_Bottom,Mesas,North_of_Valley,Plateau_South_of_Valley,
              West_Valley_Bottom,Lower_Valley,Eagle_River_Valley,Four_Corners,Grand_Valley,Headwaters,
              Lower_Gunnison,San_Juan,San_Miguel_Paradox,Upper_Gunnison,Yampa_White,North_Plains,
              South_Plains,Front_Range_Foothills,Lower_Plains,North_Front_Range,North_Park,
              South_Front_Range,South_Park,San_Luis_Valley]

# %%
def QC_report_by_region(x):
    file = create_report(x)
    f = open(file,'a')
    
    title = (yesterday + r' QA/QC Report for stations in the ' + x['region'] +
            ' region of the ' + x['drainage'] + ' drainage\n')
    
    f.write(title)
    f.write('/n')
    
    fmdf = QAQC_datapull('five_minute',x['stations'],yesterday,today)
    
    fmstation = fmdf['station'][n]
    fmdate = fmdf['date'][n]
    
    f.write('Five Minute Data/n')
    f.write('------------------/n')
    f.write('Missing Data:/n')
    f.write('----------------/n')
    
    n = 0
    for index,rows in fmdf.iterrows():
        if(pd.isnull(fmdf['tmean'][n])):
            f.write(station + 
                    ' is missing temperature data at ' + date + '/n')
        elif(pd.isnull(fmdf['rh'][n])):
            f.write(station + 
                    ' is missing relative humidity data at ' + date + '/n')
        elif(pd.isnull(fmdf['vp'][n])):
            f.write(station + ' is missing vapor pressure data at ' + date + '/n')
        elif(pd.isnull(fmdf['sr'][n])):
            f.write(station + 
                    ' is missing solar radiation data at ' + date + '/n')
        elif(pd.isnull(fmdf['ws'][n])):
            f.write(station + 
                   ' is missing wind speed data at ' + date + '/n')
        elif(pd.isnull(fmdf['wind_vec'][n])):
            f.write(station + ' is missing wind direction data at ' + date + '/n')
        elif(pd.isnull(fmdf['wind_std'][n])):
            f.write(station + 
                   ' is missing wind direction standard deviation data at ' + date + '/n')
        elif(pd.isnull(fmdf['pp'][n])):
            f.write(station + 
                   ' is missing precipitation data at ' + date + '/n')
        elif(pd.isnull(fmdf['st5'][n])):
            f.write(station + 
                   ' is missing 5cm soil temperature data at ' + date + '/n')
        elif(pd.isnull(fmdf['st15'][n])):
            f.write(station + 
                   ' is missing 15cm soil temperature data at ' + date + '/n')
        elif(pd.isnull(fmdf['gust'][n])):
            f.write(station + ' is missing gust speed data at ' + data + '/n')
        elif(pd.isnull(fmdf['gustdir'][n])):
            f.write(station + ' is missing gust direction data at ' + date + '/n')
        n = n + 1
    f.write('/n')
    f.write('/n')
        
    f.write('Temperature Data Report/n')
    f.write('-----------------------/n')
    
                    
    n = 0
    for index,rows in fmdf.iterrows():
        if fmdf['tmean'][n] > 46.1:
            f.write(station + ' reported a temperature of ' + str(data['tmean'][n]) + 
                    '°C on ' + date + '. If true, this a new state record for max temp./n')
        elif fmdf['tmean'][n] < -51.7:
            f.write(station + ' reported a temperature of ' + str(data['tmean'][n]) +
                   '°C on ' + date + '. If true, this a new state record for min temp./n')
        n = n + 1 
    f.write('/n')
    f.write('/n')
    
    f.write('Relative Humidity Data Report/n')
    f.write('------------------------------/n')
    
    n = 0
    for index,rows in fmdf.iterrows():
        if fmdf['rh'][n] > 1.0:
            f.write(station + ' reported a relative humidity of ' + str(data['rh'][n]) +
                    ' at ' + date + '/n')
        elif fmdf['rh'][n] < 0.0:
            f.write(station + ' reported negative relative humidity at ' +
                   date + '/n')
        elif fmdf['rh'][n] < 0.01:
            f.write(date + ' broke the world record for low relative humidity at ' + 
                   station + '/n')
        n = n + 1
        
    f.write('/n')
    f.write('/n')
    
    f.write('Vapor Pressure Data Report/n')
    f.write('--------------------------/n')
    #
    #
    #
    #
    
    f.write('/n')
    f.write('/n')
    
    f.write('Solar Radiation Data Report/n')
    f.write('---------------------------/n')
    n = 0
    for index,rows in fmdf.iterrows():
        if fmdf['sr'][n] < 0.0:
            f.write(station + ' reported negative solar radiation at ' + date + '/n')
        n = n + 1
    
    f.write('/n')
    f.write('/n')
    
    f.write('Wind Speed Data Report/n')
    f.write('----------------------/n')
    
    n = 0
    for index,rows in fmdf.iterrows():
        if fmdf['ws'][n] < 0.0:
            f.write(station + ' reported negative wind speed at ' + date + '/n')
        elif fmdf['ws'][0] > 77.785:
            f.write(station + ' reported a record breaking wind speed at ' + date + '/n')
        n = n + 1
        
    f.write('/n')
    f.write('/n')
    
    f.write('Wind Direction Data Report/n')
    f.write('--------------------------/n')
    
    
    n = 0 
    for index,rows in fmdf.iterrows():
        if fmdf['wind_vec'][n] < 0.0:
            f.write(station + ' reported negative wind direction at ' + date + '/n')
    
    f.write('/n')
    f.write('/n')
    
    f.write('Precipitation Data Report/n')
    f.write('-------------------------/n')
    
    n = 0
    for index,rows in fmdf.iterrows():
        if fmdf['pp'][n] > 51.562:
            f.write(station + ' reported recording breaking amount of precip at ' + date + '/n')
        elif fmdf['pp'][n] < 0.0:
            f.write(station + ' reported negative precip at ' + date + '/n')
        n = n + 1
    
    f.write('/n')
    f.write('/n')
    
    f.write('5cm Soil Temperature Data Report/n')
    f.write('--------------------------------/n')
    
    n = 0
    for index,rows in fmdf.iterrows():
        if fmdf['st5'][n] > 50.0:
            f.write(station + ' reported impossibly high 5cm soil temperature at ' +
                   date + '/n')
        elif fmdf['st5'][n] < -15.0:
            f.write(station + ' reported impossibly low 5cm soil temperature at ' + 
                   date + '/n')
        n = n + 1
    
    f.write('/n')
    f.write('/n')
    
    f.write('15cm Soil Temperature Data Report/n')
    f.write('---------------------------------/n')
    
    n = 0
    for index,rows in fmdf.iterrows():
        if fmdf['st15'][n] > 50.0:
            f.write(station + ' reported impossibly high 15cm soil temeprature at ' + 
                   date + '/n')
        elif fmdf['st15'][n] < -15.0:
            f.write(station + ' reported impossibly low 15cm soil temperature at ' + 
                   date + '/n')
        n = n + 1
    
    f.write('/n')
    f.write('/n')
    
    f.write('Gust Speed Data Report/n')
    f.write('----------------------/n')
    
    n = 0
    for index,rows in fmdf.iterrows():
        if fmdf['gust'][n] < 0.0:
            f.write(station + ' reported negative gust speed at ' + date + '/n')
        elif fmdf['gust'][n] > 77.785:
            f.write(station + ' reported a record breaking gust speed at ' + date + '/n')
        n = n + 1
    
    f.write('/n')
    f.write('/n')
    
    f.write('Gust Direction Data Report/n')
    f.write('--------------------------/n')
    
    n = 0
    for index,rows in fmdf.iterrows():
        if fmdf['gustdir'][n] < 0.0:
            f.write(station + ' reported negative gust direction at ' + date + '/n' )
        n = n + 1
        
    f.write('/n')
    f.write('/n')
    
    hdf = QAQC_datapull('hourly',x['stations'],yesterday,today)
    
    station = hdf['station'][n]
    date = hdf['date'][n]
    
    f.write('Hourly Data/n')
    f.write('------------/n')
    f.write('Missing data/n')
    f.write('------------/n')
    
    n = 0
    for index,rows in hdf.iterrows():
        if(pd.isnull(hdf['tmean'][n])):
            f.write(station + 
                    ' is missing temperature data at ' + date + '/n')
        elif(pd.isnull(hdf['rh'][n])):
            f.write(station + 
                    ' is missing relative humidity data at ' + date + '/n')
        elif(pd.isnull(hdf['vp'][n])):
            f.write(station + ' is missing vapor pressure data at ' + date + '/n')
        elif(pd.isnull(hdf['sr'][n])):
            f.write(station + 
                    ' is missing solar radiation data at ' + date + '/n')
        elif(pd.isnull(hdf['ws'][n])):
            f.write(station + 
                   ' is missing wind speed data at ' + date + '/n')
        elif(pd.isnull(hdf['wind_vec'][n])):
            f.write(station + ' is missing wind direction data at ' + date + '/n')
        elif(pd.isnull(hdf['wind_std'][n])):
            f.write(station + 
                   ' is missing wind direction standard deviation data at ' + date + '/n')
        elif(pd.isnull(hdf['pp'][n])):
            f.write(station + 
                   ' is missing precipitation data at ' + date + '/n')
        elif(pd.isnull(hdf['st5'][n])):
            f.write(station + 
                   ' is missing 5cm soil temperature data at ' + date + '/n')
        elif(pd.isnull(hdf['st15'][n])):
            f.write(station + 
                   ' is missing 15cm soil temperature data at ' + date + '/n')
        elif(pd.isnull(hdf['gust'][n])):
            f.write(station + ' is missing gust speed data at ' + data + '/n')
        elif(pd.isnull(hdf['gustdir'][n])):
            f.write(station + ' is missing gust direction data at ' + date + '/n')
        n = n + 1
    f.write('/n')
    f.write('/n')
        
    f.write('Temperature Data Report/n')
    f.write('-----------------------/n')
    
                    
    n = 0
    for index,rows in hdf.iterrows():
        if hdf['tmean'][n] > 46.1:
            f.write(station + ' reported a temperature of ' + str(data['tmean'][n]) + 
                    '°C on ' + date + '. If true, this a new state record for max temp./n')
        elif hdf['tmean'][n] < -51.7:
            f.write(station + ' reported a temperature of ' + str(data['tmean'][n]) +
                   '°C on ' + date + '. If true, this a new state record for min temp./n')
        n = n + 1 
    f.write('/n')
    f.write('/n')
    
    f.write('Relative Humidity Data Report/n')
    f.write('------------------------------/n')
    
    n = 0
    for index,rows in hdf.iterrows():
        if hdf['rh'][n] > 1.0:
            f.write(station + ' reported a relative humidity of ' + str(data['rh'][n]) +
                    ' at ' + date + '/n')
        elif hdf['rh'][n] < 0.0:
            f.write(station + ' reported negative relative humidity at ' +
                   date + '/n')
        elif hdf['rh'][n] < 0.01:
            f.write(date + ' broke the world record for low relative humidity at ' + 
                   station + '/n')
        n = n + 1
        
    f.write('/n')
    f.write('/n')
    
    f.write('Vapor Pressure Data Report/n')
    f.write('--------------------------/n')
    #
    #
    #
    #
    
    f.write('/n')
    f.write('/n')
    
    f.write('Solar Radiation Data Report/n')
    f.write('---------------------------/n')
    n = 0
    for index,rows in hdf.iterrows():
        if hdf['sr'][n] < 0.0:
            f.write(station + ' reported negative solar radiation at ' + date + '/n')
        n = n + 1
    
    f.write('/n')
    f.write('/n')
    
    f.write('Wind Speed Data Report/n')
    f.write('----------------------/n')
    
    n = 0
    for index,rows in hdf.iterrows():
        if hdf['ws'][n] < 0.0:
            f.write(station + ' reported negative wind speed at ' + date + '/n')
        elif hdf['ws'][0] > 77.785:
            f.write(station + ' reported a record breaking wind speed at ' + date + '/n')
        n = n + 1
        
    f.write('/n')
    f.write('/n')
    
    f.write('Wind Direction Data Report/n')
    f.write('--------------------------/n')
    
    
    n = 0 
    for index,rows in hdf.iterrows():
        if hdf['wind_vec'][n] < 0.0:
            f.write(station + ' reported negative wind direction at ' + date + '/n')
    
    f.write('/n')
    f.write('/n')
    
    f.write('Precipitation Data Report/n')
    f.write('-------------------------/n')
    
    n = 0
    for index,rows in hdf.iterrows():
        if hdf['pp'][n] > 51.562:
            f.write(station + ' reported recording breaking amount of precip at ' + date + '/n')
        elif hdf['pp'][n] < 0.0:
            f.write(station + ' reported negative precip at ' + date + '/n')
        n = n + 1
    
    f.write('/n')
    f.write('/n')
    
    f.write('5cm Soil Temperature Data Report/n')
    f.write('--------------------------------/n')
    
    n = 0
    for index,rows in hdf.iterrows():
        if hdf['st5'][n] > 50.0:
            f.write(station + ' reported impossibly high 5cm soil temperature at ' +
                   date + '/n')
        elif hdf['st5'][n] < -15.0:
            f.write(station + ' reported impossibly low 5cm soil temperature at ' + 
                   date + '/n')
        n = n + 1
    
    f.write('/n')
    f.write('/n')
    
    f.write('15cm Soil Temperature Data Report/n')
    f.write('---------------------------------/n')
    
    n = 0
    for index,rows in hdf.iterrows():
        if hdf['st15'][n] > 50.0:
            f.write(station + ' reported impossibly high 15cm soil temeprature at ' + 
                   date + '/n')
        elif hdf['st15'][n] < -15.0:
            f.write(station + ' reported impossibly low 15cm soil temperature at ' + 
                   date + '/n')
        n = n + 1
    
    f.write('/n')
    f.write('/n')
    
    f.write('Gust Speed Data Report/n')
    f.write('----------------------/n')
    
    n = 0
    for index,rows in hdf.iterrows():
        if hdf['gust'][n] < 0.0:
            f.write(station + ' reported negative gust speed at ' + date + '/n')
        elif hdf['gust'][n] > 77.785:
            f.write(station + ' reported a record breaking gust speed at ' + date + '/n')
        n = n + 1
    
    f.write('/n')
    f.write('/n')
    
    f.write('Gust Direction Data Report/n')
    f.write('--------------------------/n')
    
    n = 0
    for index,rows in hdf.iterrows():
        if hdf['gustdir'][n] < 0.0:
            f.write(station + ' reported negative gust direction at ' + date + '/n' )
        n = n + 1
        
    dydf = QAQC_datapull('daily',x['stations'],yesterday,today)
    
    station = dydf['station'][n]
    date = dydf['date'][n]
    
    f.write('Daily Data/n')
    f.write('----------/n')
    f.write('Missing data:/n')
    f.write('-------------/n')
    
    n = 0
    for index,rows in dydf.iterrows():
        if(pd.isnull(dydf['tmean'][n])):
            f.write(station + 
                    ' is missing temperature data at ' + date + '/n')
        elif(pd.isnull(dydf['rh'][n])):
            f.write(station + 
                    ' is missing relative humidity data at ' + date + '/n')
        elif(pd.isnull(dydf['vp'][n])):
            f.write(station + ' is missing vapor pressure data at ' + date + '/n')
        elif(pd.isnull(dydf['sr'][n])):
            f.write(station + 
                    ' is missing solar radiation data at ' + date + '/n')
        elif(pd.isnull(dydf['ws'][n])):
            f.write(station + 
                   ' is missing wind speed data at ' + date + '/n')
        elif(pd.isnull(dydf['wind_vec'][n])):
            f.write(station + ' is missing wind direction data at ' + date + '/n')
        elif(pd.isnull(dydf['wind_std'][n])):
            f.write(station + 
                   ' is missing wind direction standard deviation data at ' + date + '/n')
        elif(pd.isnull(dydf['pp'][n])):
            f.write(station + 
                   ' is missing precipitation data at ' + date + '/n')
        elif(pd.isnull(dydf['st5'][n])):
            f.write(station + 
                   ' is missing 5cm soil temperature data at ' + date + '/n')
        elif(pd.isnull(dydf['st15'][n])):
            f.write(station + 
                   ' is missing 15cm soil temperature data at ' + date + '/n')
        elif(pd.isnull(dydf['gust'][n])):
            f.write(station + ' is missing gust speed data at ' + data + '/n')
        elif(pd.isnull(dydf['gustdir'][n])):
            f.write(station + ' is missing gust direction data at ' + date + '/n')
        n = n + 1
    f.write('/n')
    f.write('/n')
        
    f.write('Temperature Data Report/n')
    f.write('-----------------------/n')
    
                    
    n = 0
    for index,rows in dydf.iterrows():
        if dydf['tmean'][n] > 46.1:
            f.write(station + ' reported a temperature of ' + str(data['tmean'][n]) + 
                    '°C on ' + date + '. If true, this a new state record for max temp./n')
        elif dydf['tmean'][n] < -51.7:
            f.write(station + ' reported a temperature of ' + str(data['tmean'][n]) +
                   '°C on ' + date + '. If true, this a new state record for min temp./n')
        n = n + 1 
    f.write('/n')
    f.write('/n')
    
    f.write('Relative Humidity Data Report/n')
    f.write('------------------------------/n')
    
    n = 0
    for index,rows in dydf.iterrows():
        if dydf['rh'][n] > 1.0:
            f.write(station + ' reported a relative humidity of ' + str(data['rh'][n]) +
                    ' at ' + date + '/n')
        elif dydf['rh'][n] < 0.0:
            f.write(station + ' reported negative relative humidity at ' +
                   date + '/n')
        elif dydf['rh'][n] < 0.01:
            f.write(date + ' broke the world record for low relative humidity at ' + 
                   station + '/n')
        n = n + 1
        
    f.write('/n')
    f.write('/n')
    
    f.write('Vapor Pressure Data Report/n')
    f.write('--------------------------/n')
    #
    #
    #
    #
    
    f.write('/n')
    f.write('/n')
    
    f.write('Solar Radiation Data Report/n')
    f.write('---------------------------/n')
    n = 0
    for index,rows in dydf.iterrows():
        if dydf['sr'][n] < 0.0:
            f.write(station + ' reported negative solar radiation at ' + date + '/n')
        n = n + 1
    
    f.write('/n')
    f.write('/n')
    
    f.write('Wind Speed Data Report/n')
    f.write('----------------------/n')
    
    n = 0
    for index,rows in dydf.iterrows():
        if dydf['ws'][n] < 0.0:
            f.write(station + ' reported negative wind speed at ' + date + '/n')
        elif dydf['ws'][0] > 77.785:
            f.write(station + ' reported a record breaking wind speed at ' + date + '/n')
        n = n + 1
        
    f.write('/n')
    f.write('/n')
    
    f.write('Wind Direction Data Report/n')
    f.write('--------------------------/n')
    
    
    n = 0 
    for index,rows in dydf.iterrows():
        if dydf['wind_vec'][n] < 0.0:
            f.write(station + ' reported negative wind direction at ' + date + '/n')
    
    f.write('/n')
    f.write('/n')
    
    f.write('Precipitation Data Report/n')
    f.write('-------------------------/n')
    
    n = 0
    for index,rows in dydf.iterrows():
        if dydf['pp'][n] > 51.562:
            f.write(station + ' reported recording breaking amount of precip at ' + date + '/n')
        elif dydf['pp'][n] < 0.0:
            f.write(station + ' reported negative precip at ' + date + '/n')
        n = n + 1
    
    f.write('/n')
    f.write('/n')
    
    f.write('5cm Soil Temperature Data Report/n')
    f.write('--------------------------------/n')
    
    n = 0
    for index,rows in dydf.iterrows():
        if dydf['st5'][n] > 50.0:
            f.write(station + ' reported impossibly high 5cm soil temperature at ' +
                   date + '/n')
        elif dydf['st5'][n] < -15.0:
            f.write(station + ' reported impossibly low 5cm soil temperature at ' + 
                   date + '/n')
        n = n + 1
    
    f.write('/n')
    f.write('/n')
    
    f.write('15cm Soil Temperature Data Report/n')
    f.write('---------------------------------/n')
    
    n = 0
    for index,rows in dydf.iterrows():
        if dydf['st15'][n] > 50.0:
            f.write(station + ' reported impossibly high 15cm soil temeprature at ' + 
                   date + '/n')
        elif dydf['st15'][n] < -15.0:
            f.write(station + ' reported impossibly low 15cm soil temperature at ' + 
                   date + '/n')
        n = n + 1
    
    f.write('/n')
    f.write('/n')
    
    f.write('Gust Speed Data Report/n')
    f.write('----------------------/n')
    
    n = 0
    for index,rows in dydf.iterrows():
        if dydf['gust'][n] < 0.0:
            f.write(station + ' reported negative gust speed at ' + date + '/n')
        elif dydf['gust'][n] > 77.785:
            f.write(station + ' reported a record breaking gust speed at ' + date + '/n')
        n = n + 1
    
    f.write('/n')
    f.write('/n')
    
    f.write('Gust Direction Data Report/n')
    f.write('--------------------------/n')
    
    n = 0
    for index,rows in dydf.iterrows():
        if dydf['gustdir'][n] < 0.0:
            f.write(station + ' reported negative gust direction at ' + date + '/n' )
        n = n + 1

# %%
QC_report_by_region(South_Park)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-aaf8a57a5217> in <module>
# ----> 1 QC_report_by_region(South_Park)
#
# <ipython-input-6-d451dd05085e> in QC_report_by_region(x)
#       9     f.write('/n')
#      10
# ---> 11     fmdf = QAQC_datapull('five_minute',x['stations'],yesterday,today)
#      12
#      13     fmstation = fmdf['station'][n]
#
# <ipython-input-2-e73db6f8bea9> in QAQC_datapull(a, b, c, d)
#      15                               '&sdate=' + c +
#      16                               '&edate=' + d +
# ---> 17                               '&elems=' + e,
#      18                               filename=csv)
#      19
#
# TypeError: can only concatenate str (not "list") to str

# %%
South_Park['stations']
# Out:
# 'bnv01,jfn01,sld01'

# %%
df = QAQC_datapull('five_minute',Four_Corners['stations'],yesterday,today)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-1359a1f18708> in <module>
# ----> 1 df = QAQC_datapull('five_minute',Four_Corners['stations'],yesterday,today)
#       2 df
#
# <ipython-input-17-b55c75f0581d> in QAQC_datapull(a, b, c, d)
#      38         r = pd.date_range(start=c,end=d,freq='D')
#      39
# ---> 40     data = data.set_index('date').reindex(r,copy=False).rename_axis('date')
#      41
#      42     return data
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     219         @wraps(func)
#     220         def wrapper(*args, **kwargs):
# --> 221             return func(*args, **kwargs)
#     222
#     223         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    3954         kwargs.pop("axis", None)
# ...
