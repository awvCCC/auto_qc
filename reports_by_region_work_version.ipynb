# %%
import os
import urllib
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
today = datetime.now().strftime('%Y-%m-%d')
yesterday = datetime.strftime(datetime.now() - timedelta(1), '%Y-%m-%d')

# %%
csv = (r'C:\Users\student\Documents\QAQC_reports\csv_vessel' + r'csv.csv')

# %%
def QAQC_datapull(a,b,c,d):
    if a == 'hourly':
        e = 'tmean,rh,vp,sr,ws,wind_vec,wind_std,pp,st5,st15,gust,gusttm,gustdir'
        r = pd.date_range(start=c,end=d,freq='H')
    elif a == 'five_minute':
        e = 'tmean,rh,vp,sr,ws,wind_vec,wind_std,pp,st5,st15,gust,gusttm,gustdir'
        r = pd.date_range(start=c,end=d,freq='5min')
    elif a == 'daily':
        e = 'tave,tmax,tmin,vp,rhmax,rhmin,sr,wrun,pp,st5mx,st5mn,st15mx,st15mn,gust,gustdir'
        r = pd.date_range(start=c,end=d,freq='D')
        
    try:
        urllib.request.urlretrieve('http://coagmet.colostate.edu/cgi-bin/web_services.pl?' +
                                  'type=' + a +
                                  '&sids=' + b +
                                  '&sdate=' + c +
                                  '&edate=' + d +
                                  '&elems=' + e,
                                  filename=csv)
    except Exception as e:
        print('Something went wrong while pulling data from ' + b + ': ' + e.args[0])
    
    
    try:
        data = pd.read_csv(csv)

        data = data.reset_index()

        headers = e.split(',')

        headers.insert(0,'date')
        headers.insert(0,'station')

        data.columns = headers

        data['date'] = pd.to_datetime(data.date)
    except Exception as e:
        print('Something went wrong while preparing data from ' + b + ': ' + e.args[0] )
    
    if a == 'hourly':
        r = pd.date_range(start=c,end=d,freq='H')
    elif a == 'five_minute':
        r = pd.date_range(start=c,end=d,freq='5min')
    elif a == 'daily':
        r = pd.date_range(start=c,end=d,freq='D')
    
    try:
        data = data.set_index('date').reindex(r,copy=False).rename_axis('date')
    except Exception as e:
        print('Something went wrong while reindexing the data from ' + b + ': ' + e.args[0])
    
    return data

# %%
def create_report(x):
    file = (x['path'] + r'\QAQC_report_' + x['drainage'] + 
            '_' + x['region'] + "_" + yesterday + '.txt')
    return file

# %%
Collegiate_Valley = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Arkansas_Drainage\Collegiate_Valley',
    'stations':'bnv01,sld01',
    'drainage':'Arkansas',
    'region':'Collegiate_Valley'
}
East_Valley_Bottom = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Arkansas_Drainage\East_Valley_Bottom',
    'stations':'hly01,hly02,lam01,lam03,lam04,mcl01',
    'drainage':'Arkansas',
    'region':'East_Valley_Bottom'
}
Mesas = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Arkansas_Drainage\Mesas',
    'stations':'cnn01,hne01,pnr01,wcf01',
    'drainage':'Arkansas',
    'region':'Mesas'
}
North_of_Valley = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Arkansas_Drainage\North_of_Valley',
    'stations':'scm01',
    'drainage':'Arkansas',
    'region':'Mesas'
}
Plateau_South_of_Valley = {
    'path': r'C:\Users\student\Documents\QAQC_reports\Arkansas_Drainage\Plateau_South_of_Valley',
    'stations':'wls01',
    'drainage':'Arkansas',
    'region':'Plateau_South_of_Valley'
}
West_Valley_Bottom = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Arkansas_Drainage\West_Valley_Bottom',
    'stations':'avn01,fwl01,ljt01,rfd01',
    'drainage':'Arkansas',
    'region':'West_Valley_Bottom'
}
Lower_Valley = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\Lower_Valley',
    'stations':'cbl01,slt01',
    'drainage':'Colorado',
    'region':'Lower_Valley'
}
Eagle_River_Valley = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\Eagle_River_Valley',
    'stations':'egl01,gyp01',
    'drainage':'Colorado',
    'region':'Eagle_River_Valley'
}
Four_Corners = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\Four_Corners',
    'stations':'ctz01,dvc01,mnc01,twc01,yjk01,yuc01',
    'drainage':'Colorado',
    'region':'Four_Corners'
}
Grand_Valley = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\Grand_Valley',
    'stations':'cbn01,frt03,orm02',
    'drainage':'Colorado',
    'region':'Grand_Valley'
}
Headwaters = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\Headwaters',
    'stations':'gby01,krm01,wfd01',
    'drainage':'Colorado',
    'region':'Headwaters'
}
Lower_Gunnison = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\Lower_Gunnison',
    'stations':'dlt01,ekt01,hot02,mtr01,oth01',
    'drainage':'Colorado',
    'region':'Lower_Gunnison'
}
San_Juan = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\San_Juan',
    'stations':'drg01,ign01,kln01,pgs01',
    'drainage':'Colorado',
    'region':'San Juan'
}
San_Miguel_Paradox = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\San_Miguel_Paradox',
    'stations':'brk01,nwd01',
    'drainage':'Colorado',
    'region': r'San_Miguel_Paradox'
}
Upper_Gunnison = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\Upper_Gunnison',
    'stations':'gun01',
    'drainage':'Colorado',
    'region':'Upper_Gunnison'
}
Yampa_White = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Colorado_Drainage\Yampa_White',
    'stations':'clk01,hyd01,mkr01',
    'drainage':'Colorado',
    'region': 'Yampa_White'
}
North_Plains = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Kansas_Drainage\North_Plains',
    'stations':'akr02,hxt01,hyk02,ilf01,pai01,stg01,wry02,yum02',
    'drainage':'Kansas',
    'region':'North_Plains'
}
South_Plains = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Kansas_Drainage\South_Plains',
    'stations':'brl02,brl03,idl01,sbt01,stn01',
    'drainage':'Kansas',
    'region':'South_Plains'
}
Front_Range_Foothills = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Platte_Drainage\Front_Range_Foothills',
    'stations':'ckp01',
    'drainage':'Platte',
    'region':'Front_Range_Foothills'
}
Lower_Plains = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Platte_Drainage\Lower_Plains',
    'stations':'brg01,hxt01,ksy01,ksy02',
    'drainage':'Platte',
    'region':'Lower_Plains'
}
North_Front_Range = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Platte_Drainage\North_Front_Range',
    'stations':'alt01,fcc01,fcl01,ftc01,ftc03,gly04,lcn01',
    'drainage':'Platte',
    'region':'North_Front_Range'
}
North_Park = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Platte_Drainage\North_Park',
    'stations':'cow01,heb01,lar01',
    'drainage':'Platte',
    'region':'North_Park'
}
South_Front_Range = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Platte_Drainage\South_Front_Range',
    'stations':'ccr01,cht01,eac01,ftl01,lsl01,pkh01',
    'drainage':'Platte',
    'region':'South_Front_Range'
}
South_Park = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Platte_Drainage\South_Park',
    'stations':'bnv01,jfn01,sld01',
    'drainage':'Platte',
    'region':'South_Park'
}
San_Luis_Valley = {
    'path':r'C:\Users\student\Documents\QAQC_reports\Rio_Grande_Drainage\San_Luis_Valley',
    'stations':'bla01,ctr01,ctr02,ljr01,san01',
    'drainage':'Rio_Grande',
    'region':'San_Luis_Valley'
}


region_list = [Collegiate_Valley,East_Valley_Bottom,Mesas,North_of_Valley,Plateau_South_of_Valley,
              West_Valley_Bottom,Lower_Valley,Eagle_River_Valley,Four_Corners,Grand_Valley,Headwaters,
              Lower_Gunnison,San_Juan,San_Miguel_Paradox,Upper_Gunnison,Yampa_White,North_Plains,
              South_Plains,Front_Range_Foothills,Lower_Plains,North_Front_Range,North_Park,
              South_Front_Range,South_Park,San_Luis_Valley]

# %%
def QC_report_by_region(x):
    file = create_report(x)
    f = open(file,'a')
    
    title = (yesterday + r' QA/QC Report for stations in the ' + x['region'] +
            ' region of the ' + x['drainage'] + ' drainage\n')
    
    f.write(title)
    f.write('\n')
    
    fmdf = pd.DataFrame()
    station_list = x['stations'].split(',')
    
    f.write('Five Minute Data\n')
    f.write('------------------\n')
    f.write('Missing Data:\n')
    f.write('----------------\n')
    
    for station in station_list:
        try:
            fmdf = fmdf.append(QAQC_datapull('five_minute',station,yesterday,today))
        except ValueError:
            f.write(station + ' is missing all five minute data\n')
    
    fmdf = fmdf.reset_index()
    
    try:
        n = 0
        fmstation = str(fmdf['station'][n])
        fmdate = str(fmdf['date'][n])
    except Exception as e:
        print('Something went wrong while creating five-minute date and station ' + 
             'variables: ' + e.args[0])
        
    try:
        n = 0
        for index,rows in fmdf.iterrows():
            if(pd.isnull(fmdf['tmean'][n])):
                f.write(fmstation + 
                        ' is missing temperature data at ' + fmdate + '\n')
            elif(pd.isnull(fmdf['rh'][n])):
                f.write(fmstation + 
                        ' is missing relative humidity data at ' + fmdate + '\n')
            elif(pd.isnull(fmdf['vp'][n])):
                f.write(fmstation + ' is missing vapor pressure data at ' + fmdate + '\n')
            elif(pd.isnull(fmdf['sr'][n])):
                f.write(fmstation + 
                        ' is missing solar radiation data at ' + fmdate + '\n')
            elif(pd.isnull(fmdf['ws'][n])):
                f.write(fmstation + 
                       ' is missing wind speed data at ' + fmdate + '\n')
            elif(pd.isnull(fmdf['wind_vec'][n])):
                f.write(fmstation + ' is missing wind direction data at ' + fmdate + '\n')
            elif(pd.isnull(fmdf['wind_std'][n])):
                f.write(fmstation + 
                       ' is missing wind direction standard deviation data at ' + fmdate + '\n')
            elif(pd.isnull(fmdf['pp'][n])):
                f.write(fmstation + 
                       ' is missing precipitation data at ' + fmdate + '\n')
            elif(pd.isnull(fmdf['st5'][n])):
                f.write(fmstation + 
                       ' is missing 5cm soil temperature data at ' + fmdate + '\n')
            elif(pd.isnull(fmdf['st15'][n])):
                f.write(fmstation + 
                       ' is missing 15cm soil temperature data at ' + fmdate + '\n')
            elif(pd.isnull(fmdf['gust'][n])):
                f.write(fmstation + ' is missing gust speed data at ' + fmdata + '\n')
            elif(pd.isnull(fmdf['gustdir'][n])):
                f.write(fmstation + ' is missing gust direction data at ' + fmdate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for missing five minute data: ' + e.args[0])
    f.write('\n')
    f.write('\n')
        
    f.write('Temperature Data Report\n')
    f.write('-----------------------\n')
    
    try:                
        n = 0
        for index,rows in fmdf.iterrows():
            if fmdf['tmean'][n] > 46.1:
                f.write(fmstation + ' reported a temperature of ' + str(data['tmean'][n]) + 
                        '°C on ' + fmdate + '. If true, this a new state record for max temp.\n')
            elif fmdf['tmean'][n] < -51.7:
                f.write(fmstation + ' reported a temperature of ' + str(data['tmean'][n]) +
                       '°C on ' + fmdate + '. If true, this a new state record for min temp.\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in five minute  temperature data: ' + 
              e.args[0])
    
    f.write('\n')
    f.write('\n')
    
    f.write('Relative Humidity Data Report\n')
    f.write('------------------------------\n')
    
    try:
        n = 0
        for index,rows in fmdf.iterrows():
            if fmdf['rh'][n] > 1.0:
                f.write(fmstation + ' reported a relative humidity of ' + str(data['rh'][n]) +
                        ' at ' + fmdate + '\n')
            elif fmdf['rh'][n] < 0.0:
                f.write(fmstation + ' reported negative relative humidity at ' +
                       date + '\n')
            elif fmdf['rh'][n] < 0.01:
                f.write(fmdate + ' broke the world record for low relative humidity at ' + 
                       fmstation + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in five minute relative humidity data: ' 
              + e.args[0])
        
    f.write('\n')
    f.write('\n')
    
    f.write('Vapor Pressure Data Report\n')
    f.write('--------------------------\n')
    #
    #
    #
    #
    
    f.write('\n')
    f.write('\n')
    
    f.write('Solar Radiation Data Report\n')
    f.write('---------------------------\n')
    try:
        n = 0
        for index,rows in fmdf.iterrows():
            if fmdf['sr'][n] < 0.0:
                f.write(fmstation + ' reported negative solar radiation at ' + fmdate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in five minute solar radiation data: ' + 
              e.argsa[0])
    
    f.write('\n')
    f.write('\n')
    
    f.write('Wind Speed Data Report\n')
    f.write('----------------------\n')
    
    try:
        n = 0
        for index,rows in fmdf.iterrows():
            if fmdf['ws'][n] < 0.0:
                f.write(fmstation + ' reported negative wind speed at ' + fmdate + '\n')
            elif fmdf['ws'][0] > 77.785:
                f.write(fmstation + ' reported a record breaking wind speed at ' + fmdate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in five minute windspeed data: ' + 
              e.args[0])
        
    f.write('\n')
    f.write('\n')
    
    f.write('Wind Direction Data Report\n')
    f.write('--------------------------\n')
    
    try:
        n = 0 
        for index,rows in fmdf.iterrows():
            if fmdf['wind_vec'][n] < 0.0:
                f.write(fmstation + ' reported negative wind direction at ' + fmdate + '\n')
    except Exception as e:
        print('Something went wrong while looking for errors in five minute wind direction data: ' + 
              e.args[0])
        
    f.write('\n')
    f.write('\n')
    
    f.write('Precipitation Data Report\n')
    f.write('-------------------------\n')
    
    try:
        n = 0
        for index,rows in fmdf.iterrows():
            if fmdf['pp'][n] > 51.562:
                f.write(fmstation + ' reported recording breaking amount of precip at ' + fmdate + '\n')
            elif fmdf['pp'][n] < 0.0:
                f.write(fmstation + ' reported negative precip at ' + fmdate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in five minute precip data: ' +
              e.args[0])
    
    f.write('\n')
    f.write('\n')
    
    f.write('5cm Soil Temperature Data Report\n')
    f.write('--------------------------------\n')
    
    try:
        n = 0
        for index,rows in fmdf.iterrows():
            if fmdf['st5'][n] > 50.0:
                f.write(fmstation + ' reported impossibly high 5cm soil temperature at ' +
                       fmdate + '\n')
            elif fmdf['st5'][n] < -15.0:
                f.write(fmstation + ' reported impossibly low 5cm soil temperature at ' + 
                       fmdate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in five minute 5cm soil temperature data: ' 
              + e.args[0])
    
    f.write('\n')
    f.write('\n')
    
    f.write('15cm Soil Temperature Data Report\n')
    f.write('---------------------------------\n')
    
    try:
        n = 0
        for index,rows in fmdf.iterrows():
            if fmdf['st15'][n] > 50.0:
                f.write(fmstation + ' reported impossibly high 15cm soil temeprature at ' + 
                       fmdate + '\n')
            elif fmdf['st15'][n] < -15.0:
                f.write(fmstation + ' reported impossibly low 15cm soil temperature at ' + 
                       fmdate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in five minute 15cm soil temperatures: '
              + e.args[0])
    
    f.write('\n')
    f.write('\n')
    
    f.write('Gust Speed Data Report\n')
    f.write('----------------------\n')
    
    try:
        n = 0
        for index,rows in fmdf.iterrows():
            if fmdf['gust'][n] < 0.0:
                f.write(fmstation + ' reported negative gust speed at ' + fmdate + '\n')
            elif fmdf['gust'][n] > 77.785:
                f.write(fmstation + ' reported a record breaking gust speed at ' + fmdate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in five minute gust speed data: ' + 
              e.args[0])
    
    f.write('\n')
    f.write('\n')
    
    f.write('Gust Direction Data Report\n')
    f.write('--------------------------\n')
    
    try:
        n = 0
        for index,rows in fmdf.iterrows():
            if fmdf['gustdir'][n] < 0.0:
                f.write(fmstation + ' reported negative gust direction at ' + fmdate + '\n' )
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in five minute gust direction data: ' + 
              e.args[0])
    
    f.write('\n')
    f.write('\n')
    
    hdf = pd.DataFrame()
    
    f.write('Hourly Data\n')
    f.write('------------\n')
    f.write('Missing data\n')
    f.write('------------\n')
    
    for station in station_list:
        try:
            hdf = hdf.append(QAQC_datapull('hourly',station,yesterday,today))
        except ValueError:
            f.write(station + ' is missing all hourly data\n')
    
    hdf = hdf.reset_index()
    
    try:
        n = 0    
        hstation = str(hdf['station'][n])
        hdate = str(hdf['date'][n])
    except Exception as e:
        print('Something went wrong while creating hourly date and station variables: ' +
             e.args[0])

    try:   
        n = 0
        for index,rows in hdf.iterrows():
            if(pd.isnull(hdf['tmean'][n])):
                f.write(hstation + 
                        ' is missing temperature data at ' + hdate + '\n')
            elif(pd.isnull(hdf['rh'][n])):
                f.write(hstation + 
                        ' is missing relative humidity data at ' + hdate + '\n')
            elif(pd.isnull(hdf['vp'][n])):
                f.write(hstation + ' is missing vapor pressure data at ' + hdate + '\n')
            elif(pd.isnull(hdf['sr'][n])):
                f.write(hstation + 
                        ' is missing solar radiation data at ' + hdate + '\n')
            elif(pd.isnull(hdf['ws'][n])):
                f.write(hstation + 
                       ' is missing wind speed data at ' + hdate + '\n')
            elif(pd.isnull(hdf['wind_vec'][n])):
                f.write(hstation + ' is missing wind direction data at ' + hdate + '\n')
            elif(pd.isnull(hdf['wind_std'][n])):
                f.write(hstation + 
                       ' is missing wind direction standard deviation data at ' + hdate + '\n')
            elif(pd.isnull(hdf['pp'][n])):
                f.write(hstation + 
                       ' is missing precipitation data at ' + hdate + '\n')
            elif(pd.isnull(hdf['st5'][n])):
                f.write(hstation + 
                       ' is missing 5cm soil temperature data at ' + hdate + '\n')
            elif(pd.isnull(hdf['st15'][n])):
                f.write(hstation + 
                       ' is missing 15cm soil temperature data at ' + hdate + '\n')
            elif(pd.isnull(hdf['gust'][n])):
                f.write(station + ' is missing gust speed data at ' + hdate + '\n')
            elif(pd.isnull(hdf['gustdir'][n])):
                f.write(station + ' is missing gust direction data at ' + hdate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for missing hourly data: ' + e.args[0])
    f.write('\n')
    f.write('\n')
        
    f.write('Temperature Data Report\n')
    f.write('-----------------------\n')
    
    try:                
        n = 0
        for index,rows in hdf.iterrows():
            if hdf['tmean'][n] > 46.1:
                f.write(hstation + ' reported a temperature of ' + str(data['tmean'][n]) + 
                        '°C on ' + hdate + '. If true, this a new state record for max temp.\n')
            elif hdf['tmean'][n] < -51.7:
                f.write(hstation + ' reported a temperature of ' + str(data['tmean'][n]) +
                       '°C on ' + hdate + '. If true, this a new state record for min temp.\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in hourly temperature data:' + e.args[0])
    
    f.write('\n')
    f.write('\n')
    
    f.write('Relative Humidity Data Report\n')
    f.write('-----------------------------\n')
    
    try:
        n = 0
        for index,rows in hdf.iterrows():
            if hdf['rh'][n] > 1.0:
                f.write(hstation + ' reported a relative humidity of ' + str(data['rh'][n]) +
                        ' at ' + hdate + '\n')
            elif hdf['rh'][n] < 0.0:
                f.write(hstation + ' reported negative relative humidity at ' +
                       hdate + '\n')
            elif hdf['rh'][n] < 0.01:
                f.write(hstation + ' broke the world record for low relative humidity at ' + 
                       hdate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in hourly relative humidity data: ' + 
             e.args[0])
        
    f.write('\n')
    f.write('\n')
    
    f.write('Vapor Pressure Data Report\n')
    f.write('--------------------------\n')
    #
    #
    #
    #
    
    f.write('\n')
    f.write('\n')
    
    f.write('Solar Radiation Data Report\n')
    f.write('---------------------------\n')
    try:
        n = 0
        for index,rows in hdf.iterrows():
            if hdf['sr'][n] < 0.0:
                f.write(hstation + ' reported negative solar radiation at ' + hdate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in hourly solar radiation data: ' +
             e.args[0])
    f.write('\n')
    f.write('\n')
    
    f.write('Wind Speed Data Report\n')
    f.write('----------------------\n')
    
    try:
        n = 0
        for index,rows in hdf.iterrows():
            if hdf['ws'][n] < 0.0:
                f.write(hstation + ' reported negative wind speed at ' + hdate + '\n')
            elif hdf['ws'][0] > 77.785:
                f.write(hstation + ' reported a record breaking wind speed at ' + hdate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in hourly wind speed data: ' + 
             e.args[0])
        
    f.write('\n')
    f.write('\n')
    
    f.write('Wind Direction Data Report\n')
    f.write('--------------------------\n')
    
    try:
        n = 0 
        for index,rows in hdf.iterrows():
            if hdf['wind_vec'][n] < 0.0:
                f.write(station + ' reported negative wind direction at ' + hdate + '\n')
    except Exception as e:
        print('Something went wrong while looking for errors in hourly wind direction data:' + 
             e.args[0])
    
    f.write('\n')
    f.write('\n')
    
    f.write('Precipitation Data Report\n')
    f.write('-------------------------\n')
    
    try:
        n = 0
        for index,rows in hdf.iterrows():
            if hdf['pp'][n] > 51.562:
                f.write(hstation + ' reported recording breaking amount of precip at ' + hdate + '\n')
            elif hdf['pp'][n] < 0.0:
                f.write(hstation + ' reported negative precip at ' + hdate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in hourly precip data: ' + e.args[0])
    
    f.write('\n')
    f.write('\n')
    
    f.write('5cm Soil Temperature Data Report\n')
    f.write('--------------------------------\n')
    
    try:
        n = 0
        for index,rows in hdf.iterrows():
            if hdf['st5'][n] > 50.0:
                f.write(hstation + ' reported impossibly high 5cm soil temperature at ' +
                       hdate + '\n')
            elif hdf['st5'][n] < -15.0:
                f.write(hstation + ' reported impossibly low 5cm soil temperature at ' + 
                       hdate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrhile while looking for errors in hourly 5cm soil temperature: ' + 
             e.args[0])
    
    f.write('\n')
    f.write('\n')
    
    f.write('15cm Soil Temperature Data Report\n')
    f.write('---------------------------------\n')
    
    try:
        n = 0
        for index,rows in hdf.iterrows():
            if hdf['st15'][n] > 50.0:
                f.write(hstation + ' reported impossibly high 15cm soil temeprature at ' + 
                       hdate + '\n')
            elif hdf['st15'][n] < -15.0:
                f.write(hstation + ' reported impossibly low 15cm soil temperature at ' + 
                       hdate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in hourly 15cm soil temperature: ' + 
             e.args[0])
    
    f.write('\n')
    f.write('\n')
    
    f.write('Gust Speed Data Report\n')
    f.write('----------------------\n')
    
    try:
        n = 0
        for index,rows in hdf.iterrows():
            if hdf['gust'][n] < 0.0:
                f.write(hstation + ' reported negative gust speed at ' + hdate + '\n')
            elif hdf['gust'][n] > 77.785:
                f.write(hstation + ' reported a record breaking gust speed at ' + hdate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in hourly gust speed data: ' + 
             e.args[0])
    
    
    f.write('\n')
    f.write('\n')
    
    f.write('Gust Direction Data Report\n')
    f.write('--------------------------\n')
    
    try:
        n = 0
        for index,rows in hdf.iterrows():
            if hdf['gustdir'][n] < 0.0:
                f.write(hstation + ' reported negative gust direction at ' + hdate + '\n' )
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in hourly gust direction data: ' + 
             e.args[0])
    
    f.write('Daily Data\n')
    f.write('----------\n')
    f.write('Missing data:\n')
    f.write('-------------\n')     
    
    dydf = pd.DataFrame()
    
    for station in station_list:
        try:
            dydf = dydf.append(QAQC_datapull('daily',station,yesterday,today))
        except ValueError:
            f.write(station + ' is missing all daily data\n')
    
    dydf = dydf.reset_index()
    
    try:
        n = 0
        dystation = str(dydf['station'][n])
        dydate = str(dydf['date'][n])
    except Exception as e:
        print('Something went wrong while creating daily data and station variables: ' +
             e.args[0])
    
    try:
        n = 0
        for index,rows in dydf.iterrows():
            if(pd.isnull(dydf['tave'][n])):
                f.write(dystation + 
                        ' is missing daily average temperature data at ' + dydate + '\n')
            elif(pd.isnull(dydf['tmax'][n])):
                f.write(dystation + 
                       ' is missing daily maximum temperature data at ' + dydate + '\n')
            elif(pd.isnull(dydf['tmin'][n])):
                f.write(dystation + 
                   ' is missing daily minimum temperature data at ' + dydate + '\n')
            elif(pd.isnull(dydf['rhmax'][n])):
                f.write(dystation + 
                        ' is missing daily maximum relative humidity data at ' + dydate + '\n')
            elif(pd.isnull(dydf['rhmin'][n])):
                f.write(dystation + 
                        ' is missing daily minimum relative humidity data at ' + dydate + '\n')
            elif(pd.isnull(dydf['vp'][n])):
                f.write(dystation + ' is missing vapor pressure data at ' + dydate + '\n')
            elif(pd.isnull(dydf['sr'][n])):
                f.write(dystation + ' is missing solar radiation data at ' + dydate + '\n')
            elif(pd.isnull(dydf['st5mx'][n])):
                f.write(dystation + ' is missing maximum daily 5cm soil temperature data at ' + 
                       dydate + '\n')
            elif(pd.isnull(dydf['st5mn'][n])):
                f.write(dystation + ' is missing minimum daily 5cm soil temperature data at ' + 
                       dydate + '\n')
            elif(pd.isnull(dydf['st15mx'][n])):
                f.write(dystation + ' is missing maximum daily 15cm soil temperature data at ' + 
                       dydate + '\n')
            elif(pd.isnull(dydf['st15mn'][n])):
                f.write(dystation + ' is missing minimum daily 15cm soil temperature data at ' + 
                       dydate + '\n')
            elif(pd.isnull(dydf['pp'][n])):
                f.write(dystation + ' is missing precipitation data at ' + dydate + '\n')
            elif(pd.isnull(dydf['gust'][n])):
                f.write(dystation + ' is missing gust speed data at ' + dydate + '\n')
            elif(pd.isnull(dydf['gustdir'][n])):
                f.write(dystation + ' is missing gust direction data at ' + dydate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for daily missing data: ' + e.args[0])
   
    f.write('\n')
    f.write('\n')
        
    f.write('Temperature Data Report\n')
    f.write('-----------------------\n')
    
    try:                
        n = 0
        for index,rows in dydf.iterrows():
            if dydf['tave'][n] > 46.1:
                f.write(dystation + ' reported a average daily temperature of ' +
                        str(data['tave'][n]) + '°C on ' + dydate + 
                        '. If true, this is a new state record for max temp.\n')
            elif dydf['tave'][n] < -51.7:
                f.write(dystation + ' reported a averge daily temperature of ' + 
                        str(data['tave'][n]) + '°C on ' + dydate +
                        '. If true, this is a new state record for min temp.\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in daily average temperature data: ' + 
             e.args[0])
    try:
        n = 0
        for index,rows in dydf.iterrows():
            if dydf['tmax'][n] > 46.1:
                f.write(dystation + ' reported a maximum daily temperature of ' +
                        str(data['tmax'][n]) + '°C on ' + dydate + 
                        '. If true, this is a new state record for max temp.\n')
            elif dydf['tmax'][n] < -51.7:
                f.write(dystation + ' reported a maximum daily temperature of ' + 
                        str(data['tmax'][n]) + '°C on ' + dydate +
                        '. If true, this is a new state record for min temp.\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in daily maximum temperature data:' + 
             e.args[0])
        
    try:
        n = 0
        for index,rows in dydf.iterrows():
            if dydf['tmin'][n] > 46.1:
                f.write(dystation + ' reported a minimum daily temperature of ' +
                        str(data['tmin'][n]) + '°C on ' + dydate + 
                        '. If true, this is a new state record for max temp.\n')
            elif dydf['tmin'][n] < -51.7:
                f.write(dystation + ' reported a minimum daily temperature of ' + 
                        str(data['tmin'][n]) + '°C on ' + dydate +
                        '. If true, this is a new state record for min temp.\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in daily minimum temperature data:' + 
             e.args[0])     

        
    f.write('\n')
    f.write('\n')
    
    f.write('Relative Humidity Data Report\n')
    f.write('-----------------------------\n')
    
    try:
        n = 0
        for index,rows in dydf.iterrows():
            if dydf['rhmax'][n] > 1.0:
                f.write(dystation + ' reported a daily maximum relative humidity of ' +
                        str(data['rhmax'][n]) + ' at ' + dydate + '\n')
            elif dydf['rhmax'][n] < 0.0:
                f.write(dystation + ' reported negative daily maximum relative humidity at ' +
                       dydate + '\n')
            elif dydf['rhmax'][n] < 0.01:
                f.write(dystation + ' broke the world record for low relative humidity at ' + 
                       dydate + '\n')
            n = n + 1
    except Exception as e: 
        print('Something went wrong while looking for errors in daily maximum relative' +
              ' humidity data: ' + e.args[0])
        
    try:
        n = 0
        for index,rows in dydf.iterrows():
            if dydf['rhmin'][n] > 1.0:
                f.write(dystation + ' reported a daily minimum relative humidity of ' +
                        str(data['rhmin'][n]) + ' at ' + dydate + '\n')
            elif dydf['rhmin'][n] < 0.0:
                f.write(dystation + ' reported negative daily minimum relative humidity at ' +
                       dydate + '\n')
            elif dydf['rhmin'][n] < 0.01:
                f.write(dystation + ' broke the world record for low relative humidity at ' + 
                       dydate + '\n')
            n = n + 1
    except Exception as e: 
        print('Something went wrong while looking for errors in daily minimum relative' +
              ' humidity data: ' + e.args[0])
        
    f.write('\n')
    f.write('\n')
    
    f.write('Vapor Pressure Data Report\n')
    f.write('--------------------------\n')
    #
    #
    #
    #
    
    f.write('\n')
    f.write('\n')
    
    f.write('Solar Radiation Data Report\n')
    f.write('---------------------------\n')
    
    try:
        n = 0
        for index,rows in dydf.iterrows():
            if dydf['sr'][n] < 0.0:
                f.write(dystation + ' reported negative solar radiation at ' + dydate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in daily solar radiation data: ' + 
             e.args[0])
        
    f.write('\n')
    f.write('\n')
    
    f.write('Precipitation Data Report\n')
    f.write('-------------------------\n')
    
    try:
        n = 0
        for index,rows in dydf.iterrows():
            if dydf['pp'][n] > 51.562:
                f.write(dystation + ' reported recording breaking amount of precip at ' + dydate + '\n')
            elif dydf['pp'][n] < 0.0:
                f.write(dystation + ' reported negative precip at ' + dydate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in daily precip data ' + e.argsa[0])
    
    f.write('\n')
    f.write('\n')
    
    f.write('5cm Soil Temperature Data Report\n')
    f.write('--------------------------------\n')
    
    try:
        n = 0
        for index,rows in dydf.iterrows():
            if dydf['st5mx'][n] > 50.0:
                f.write(dystation + ' reported impossibly high daily maximum 5cm soil' +
                        ' temperature at ' + dydate + '\n')
            elif dydf['st5mx'][n] < -15.0:
                f.write(dystation + ' reported impossibly low daily maximum 5cm soil' +
                        ' temperature at ' + dydate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in daily maximum 5cm' +
              ' soil temperature data: ' + e.args[0])
    
    try:
        n = 0
        for index,rows in dydf.iterrows():
            if dydf['st5mn'][n] > 50.0:
                f.write(dystation + ' reported impossibly high daily minimum 5cm soil' +
                        ' temperature at ' + dydate + '\n')
            elif dydf['st5mn'][n] < -15.0:
                f.write(dystation + ' reported impossibly low daily minimum 5cm soil' +
                        ' temperature at ' + dydate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in daily minimum 5cm' +
              ' soil temperature data: ' + e.args[0])
    
    f.write('\n')
    f.write('\n')
    
    f.write('15cm Soil Temperature Data Report\n')
    f.write('---------------------------------\n')
    
    try:
        n = 0
        for index,rows in dydf.iterrows():
            if dydf['st15mx'][n] > 50.0:
                f.write(dystation + ' reported impossibly high daily maximum 15cm soil' +
                        ' temeprature at ' + dydate + '\n')
            elif dydf['st15mx'][n] < -15.0:
                f.write(dystation + ' reported impossibly low daily maximum 15cm soil' +
                        ' temperature at ' + dydate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in daily maximum 15cm' +
              ' soil temperature data: ' + e.args[0])
        
    try:
        n = 0
        for index,rows in dydf.iterrows():
            if dydf['st15mn'][n] > 50.0:
                f.write(dystation + ' reported impossibly high daily minimum 15cm soil' +
                        ' temeprature at ' + dydate + '\n')
            elif dydf['st15mn'][n] < -15.0:
                f.write(dystation + ' reported impossibly low daily minimum 15cm soil' +
                        ' temperature at ' + dydate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in daily minimum 15cm' +
              ' soil temperature data: ' + e.args[0])
        
    f.write('\n')
    f.write('\n')
    
    f.write('Gust Speed Data Report\n')
    f.write('----------------------\n')
    
    try:
        n = 0
        for index,rows in dydf.iterrows():
            if dydf['gust'][n] < 0.0:
                f.write(dystation + ' reported negative gust speed at ' + dydate + '\n')
            elif dydf['gust'][n] > 77.785:
                f.write(dystation + ' reported a record breaking gust speed at ' + dydate + '\n')
            n = n + 1
    except Exception as e:
        print('Something went wrong while looking for errors in daily gust speed data: ' + e.args[0])
    
    f.write('\n')
    f.write('\n')
    
    f.write('Gust Direction Data Report\n')
    f.write('--------------------------\n')
    
    try:
        n = 0
        for index,rows in dydf.iterrows():
            if dydf['gustdir'][n] < 0.0:
                f.write(dystation + ' reported negative gust direction at ' + dydate + '\n' )
            n = n + 1
    except Exception as e:
        print('Something went wrong while checking for errors in daily gust direction data: ' +
             e.args[0])
        
    f.close()

# %%
QC_report_by_region(South_Park)
