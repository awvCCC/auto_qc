# %%
from datetime import datetime,timedelta

# %%
today = datetime.now().strftime('%Y-%m-%d')

# %%
class Station:
    
    def __init__(self,drainage,region,name,lat,long,elevation,fobs,lobs,irrigation):
        self.drainage = drainage
        self.region = region
        self.name = name
        self.lat = lat
        self.long = long
        self.fobs = fobs
        self.lobs = lobs
        self.irrigation = irrigation

# %%
akr02 = Station('Kansas',
                'North Plains',
                'Akron',
                40.1548,
                -103.1420,
                4537,
                '1992-07-01',
                today,
                'Dry')
alt01 = Station('Platte',
                'North Front Range',
                'Ault',
                40.5690,
                -104.72,
                4910,
                '1992-05-17',
                today,
                'Full')
avn01 = Station('Arkansas',
                'West Valley Bottom',
                'Avondale',
                38.2056,
                -104.3290,
                4630,
                '1992-06-04',
                today,
                'Full')
bla01 = Station('Rio Grande',
                'San Luis Valley',
                'Blanca',
                37.3905,
                -105.5570,
                7755,
                '1992-02-24',
                '2018-10-02','Dry')
bnv01 = Station('Arkansas',
                'Collegiate Valley',
                'Buena Vista',
                38.8315,
                -106.129,
                7900,
                '2010-10-12',
                today,
                'Partial')
brg01 = Station('Platte',
                'Lower Plains',
                'Briggsdale',
                40.5947,
                -104.3190,
                4858,
                '2002-07-31',
                today,
                'Dry')
brk01 = Station('Colorado',
                'San Miguel',
                'Bedrock',
                38.3279,
                -108.855,
                4973,
                '2013-11-07',
                today,
                'Dry')
brl01 = Station('Kansas',
                'South Plains',
                'Burlington North',
                39.4998,
                -102.074,
                3900,
                '1992-05-07',
                '2012-01-02',
                'Partial')
brl02 = Station('Kansas',
                'South Plains',
                'Burlington South',
                39.2651,
                -102.109,
                4170,
                '1992-01-02',
                today,
                'Dry')
brl03 = Station('Kansas',
                'South Plains',
                'Burlinton 3',
                39.3374,
                -102.196,
                4068,
                '2008-05-21',
                today,
                'Full')
cbl01 = Station('Colorado',
                'Lower Valley',
                'Carbondale',
                39.3623,
                -107.208,
                6293,
                '2015-05-08',
                today,
                'Full')
cbn01 = Station('Colorado',
                'Grand Valley',
                'Collbran',
                39.1993,
                -107.99,
                6555,
                '2018-03-30',
                today,
                'Full')
ccr01 = Station('Platte',
                'South Front Range',
                'Cherry Creek Res',
                39.6059,
                -104.834,
                5632,
                '2019-07-25',
                today,
                'Dry')
cdg01 = Station('Colorado',
                'Grand Valley',
                'Cedaredge',
                38.9142,
                -107.932,
                6404,
                '2006-02-18',
                '2015-05-06',
                'Full')
cht01 = Station('Platte',
                'South Front Range',
                'Chatfield',
                39.5741,
                -105.054,
                5414,
                '2019-12-04',
                today,
                'Dry')
ckp01 = Station('Platte',
                'Front Range Foothills',
                'Cherokee Park',
                40.8263,
                -105.267,
                5956,
                '2014-07-25',
                today,
                'Dry')
clk01 = Station('Colorado',
                'Yampa',
                'Clark',
                40.7043,
                -106.934,
                7221,
                '2018-04-25',
                today,
                'Full')
cnn01 = Station('Arkansas',
                'Mesas',
                'Canon City',
                38.4425,
                -105.176,
                5344,
                '2010-12-31',
                today,
                'Partial')
cow01 = Station('Platte',
                'North Park',
                'Cowdry',
                40.8659,
                -106.336,
                7895,
               '2009-06-10',
                today,
                'Full')
ctr01 = Station('Rio Grande',
                'San Luis Valley',
                'Center',
                37.7067,
                -106.144,
                7702,
                '1993-10-08',
                today,
                'Partial')
ctr02 = Station('Rio Grande',
                'San Luis Valley',
                'Center 2',
                37.8288,
                -106.038,
                7608,
                '2003-10-02',
                today,
                'Partial')
ctz01 = Station('Colorado',
                'Four Corners',
                'Cortez',
                37.2246,
                -108.673,
                6015,
                '1992-01-02',
                today,
                'Full')
dlt01 = Station('Colorado',
                'Lower Gunnison',
                'Delta',
                37.7345,
                -108.119,
                5010,
                '1995-04-19',
                today,
                'Partial')
drg01 = Station('Colorado',
                'San Juan',
                'Durango',
                37.1125,
                -107.881,
                6203,
                '2018-05-30',
                today,
                'Full')
dvc01 = Station('Colorado',
                'Four Corners',
                'Dove Creek',
                37.7265,
                -108.954,
                6595,
                '1992-10-28',
                today,
                'Dry')
eac01 = Station('Platte',
                'South Front Range',
                'Eastern Adams County',
                39.7857,
                -103.798,
                4907,
                '2000-07-17',
                today,
                'Dry')
egl01 = Station('Colorado',
                'Eagle River Valley',
                'Eagle',
                39.6308,
                -106.782,
                6894,
                '2019-11-19',
                today,
                'Full')
ekt01 = Station('Colorado',
                'Lower Gunnison',
                'Eckert',
                38.8398,
                -107.973,
                5522,
                '2015-05-07',
                today,
                'Full')
frt02 = Station('Colorado',
                'Grand Valley',
                'Fruita 2',
                39.1803,
                -108.699,
                4519,
                '1992-06-16',
                '2019-11-08',
                'Partial')
frt03 = Station('Colorado',
                'Grand Valley',
                'Fruita 3',
                39.183,
                -108.697,
                4605,
                '2019-09-25',
                today,
                'Partial')
ftc01 = Station('Platte',
                'North Front Range',
                'Fort Collins AERC',
                40.5947,
                -105.137,
                5120,
                '1992-02-01',
                today,
                'Partial')
ftc03 = Station('Platte',
                'North Front Range',
                'Fort Collins ARDEC',
                40.3525,
                -105.0,
                5110,
                '1992-05-08',
                today,
                'Partial')
ftm01 = Station('Platte',
                'Lower Plains',
                'Fort Morgan',
                40.2585,
                -103.954,
                4320,
                '1995-04-25',
                '2010-04-06',
                'Partial')
fwl01 = Station('Arkansas',
                'West Valley Bottom',
                'Fowler',
                38.1351,
                -104.032,
                4335,
                '2005-05-17',
                today,
                'Full')
gby01 = Station('Colorado',
                'Headwaters',
                'Granby',
                40.1047,
                -105.943,
                7911,
                '2018-04-23',
                today,
                'Full')
gjc01 = Station('Colorado',
                'Grand Valley',
                'Grand Junction',
                39.1752,
                -108.632,
                4869,
                '1993-10-01',
                '2009-05-10',
                'Dry')
gly03 = Station('Platte',
                'North Front Range',
                'Greeley 3',
                40.4394,
                -104.647,
                4680,
                '1992-03-04',
                '2010-06-15',
                'Partial')
gly04 = Station('Platte',
                'North Front Range',
                'Greeley 4',
                40.4487,
                -104.638,
                4683,
                '2008-06-05',
                today,
                'Full')
gun01 = Station('Colorado',
                'Upper Gunnison',
                'Gunnison',
                38.6135,
                -106.901,
                7894,
                '2015-02-25',
                today,
                'Full')
gyp01 = Station('Colorado',
                'Eagle River Valley',
                'Gypsum',
                39.6344,
                -106.947,
                6470,
                '2017-10-11',
                today,
                'Partial')
heb01 = Station('Platte',
                'North Park',
                'Hebron',
                40.5455,
                -106.388,
                8170,
               '2009-06-10',
                today,
                'Full')
hly01 = Station('Arkansas',
                'East Valley Bottom',
                'Holly',
                38.07,
                -102.09,
                3636,
                '2001-09-27',
                today,
                'Partial')
hly02 = Station('Arkansas',
                'East Valley Bottom',
                'Holly 2',
                38.1361,
                -102.241,
                3570,
                '2005-05-21',
                today,
                'Full')
hne01 = Station('Arkansas',
                'Mesas',
                'Hoehne',
                37.2893,
                -104.313,
                5625,
                '2000-02-14',
                today,
                'Partial')
hot01 = Station('Colorado',
                'Lower Gunnison',
                'Rogers Mesa 1',
                38.7919,
                -107.792,
                5547,
                '1998-05-21',
                '2019-09-25',
                'Partial')
hot02 = Station('Colorado',
                'Lower Gunnison',
                'Rogers Mesa 2',
                38.7985,
                -107.788,
                5631,
                '2019-03-19',
                today,
                'Full')
hxt01 = Station('Kansas',
                'North Plains',
                'Haxtun',
                40.6722,
                -102.647,
                4040,
                '1997-03-27',
                today,
                'Partial')
hyd01 = Station('Colorado',
                'Yampa',
                'Hayden',
                40.499,
                -107.181,
                6454,
                '2001-11-16',
                today,
                'Full')
hyk02 = Station('Kansas',
                'North Plains',
                'Holyoke',
                40.4909,
                -102.089,
                3735,
                '1992-01-02',
                today,
                'Dry')
idl01 = Station('Kansas',
                'South Plains',
                'Idalia',
                39.7312,
                -102.302,
                3975,
                '1992-01-02',
                today,
                'Full')
ign01 = Station('Colorado',
                'San Juan',
                'Ignacio',
                37.1383,
                -107.707,
                6617,
                '2018-04-20',
                today,
                'Full')
ilf01 = Station('Kansas',
                'North Plains',
                'Iliff',
                40.7678,
                -103.045,
                3822,
                '2008-02-02',
                today,
                'Dry')
jfn01 = Station('Platte',
                'South Park',
                'Jefferson',
                39.3509,
                -105.8150,
                9460,
                '2012-01-01',
                today,
                'Dry')
kln01 = Station('Colorado',
                'San Juan',
                'Kline',
                37.1261,
                -108.1460,
                6755,
                '2018-04-12',
                today,
                'Partial')
krk01 = Station('Kansas',
                'South Plains',
                'Kirk',
                39.6554,
                -102.621,
                4213,
                '1996-05-13',
                today,
                'Partial')
krm01 = Station('Colorado',
                'Headwaters',
                'Kremmling',
                40.1154,
                -106.283,
                7534,
                '2018-04-30',
                today,
                'Full')
ksy01 = Station('Platte',
                'Lower Plains',
                'Kersey 1',
                40.3768,
                -104.532,
                4625,
                '1992-05-01',
                today,
                'Partial')
ksy02 = Station('Platte',
                'Lower Plains',
                'Kersey 2',
                40.3629,
                -104.478,
                4563,
                '2015-01-01',
                today,
                'Partial')
lam01 = Station('Arkansas',
                'East Valley Bottom',
                'Lamar 1',
                37.9807,
                -102.596,
                3776,
                '1996-08-03',
                today,
                'Dry')
lam03 = Station('Arkansas',
                'East Valley Bottom',
                'Lamar 3',
                37.9798,
                -102.713,
                3918,
                '2002-07-31',
                today,
                'Dry')
lam04 = Station('Arkansas',
                'East Valley Bottom',
                'Lamar 4',
                38.1539,
                -102.599,
                3705,
                '2005-05-11',
                today,
                'Full')
lar01 = Station('Platte',
                'North Park',
                'Larand',
                40.6126,
                -106.3,
                8252,
                '2009-06-10',
                today,
                'Full')
lcn01 = Station('Platte',
                'North Front Range',
                'Lucerne',
                40.4756,
                -104.707,
                4750,
                '1992-03-04',
                today,
                'Partial')
ljr01 = Station('Rio Grande',
                'San Luis Valley',
                'LaJara',
                37.2443,
                -105.972,
                7595,
                '2005-05-19',
                today,
                'Partial')
ljt01 = Station('Arkansas',
                'West Valley Bottom',
                'LaJunta',
                38.0778,
                -103.366,
                3960,
                '2005-03-17',
                today,
                'Full')
lsl01 = Station('Platte',
                'South Front Range',
                'La Salle',
                40.3349,
                -104.63,
                4676,
                '2012-02-10',
                today,
                'Partial')
mcl01 = Station('Arkansas',
                'East Valley Bottom',
                'McClave',
                38.1475,
                -102.859,
                3895,
                '2005-03-17',
                today,
                'Full')
mkr01 = Station('Colorado',
                'Yampa',
                'Meeker',
                40.0083,
                -107.908,
                6342,
                '2018-04-26',
                today,
                'Full')
mnc01 = Station('Colorado',
                'Four Corners',
                'Mancos',
                37.3212,
                -108.339,
                6730,
                '2010-10-29',
                today,
                'Full')
mtr01 = Station('Colorado',
                'Lower Gunnison',
                'Montrose',
                38.547,
                -107.914,
                5651,
                '2015-02-24',
                today,
                'Full')
nwd01 = Station('Colorado',
                'San Miguel',
                'Norwood',
                38.1510,
                -108.284,
                7000,
                '2018-06-14',
                today,
                'Partial')
orm01 = Station('Colorado',
                'Grand Valley',
                'Orchard Mesa 1',
                39.0424,
                -108.466,
                4700,
                '2006-01-02',
                '2019-09-24',
                'Partial')
orm02 = Station('Colorado',
                'Grand Valley',
                'Orchard Mesa 2',
                39.0441,
                -108.467,
                4700,
                '2019-09-25',
                today,
                'Partial')
oth01 = Station('Colorado',
                'Lower Gunnison',
                'Olathe',
                38.6351,
                -107.964,
                5324,
               '1992-07-28',
                today,
                'Partial')
pai01 = Station('Kansas',
                'North Plains',
                'Paoli',
                40.4248,
                -102.475,
                3875,
                '2001-09-26',
                today,
                'Dry')
pgs01 = Station('Colorado',
                'San Juans',
                'Pagosa Springs',
                37.277,
                -106.983,
                7181,
                '2018-04-20',
                today,
                'Full')
pkh01 = Station('Platte',
                'South Front Range',
                'Peckham',
                40.3125,
                -104.7270,
                4701,
                '1992-03-17',
                today,
                'Partial')
pkr01 = Station('Platte',
                'South Front Range',
                'Parker',
                39.5505,
                -104.811,
                5813,
                '2015-03-12',
                '2019-07-24',
                'Dry')
pnr01 = Station('Arkansas',
                'Mesas',
                'Penrose',
                38.4119,
                -104.998,
                5331,
                '2010-10-13',
                today,
                'Full')
rfd01 = Station('Arkansas',
                'East Valley Bottom',
                'Rocky Ford',
                38.0385,
                -103.695,
                4180,
                '1992-06-04',
                today,
                'Full')
san01 = Station('Rio Grande',
                'San Luis Valley',
                'San Acacio',
                37.1417,
                -105.6110,
                7753,
                '2000-08-12',
                today,
                'Dry')
sbt01 = Station('Kansas',
                'South Plains',
                'Seibert',
                39.1187,
                -102.925,
                4852,
                '2015-04-02',
                today,
                'Dry')
scm01 = Station('Arkansas',
                'North of Valley',
                'Sand Creek',
                38.5439,
                -102.503,
                3963,
                '2008-07-24',
                today,
                'Dry')
sld01 = Station('Arkansas',
                'Collegiate Valley',
                'Salida',
                38.5713,
                -102.043,
                7227,
                '2010-07-28',
                today,
                'Full')
slt01 = Station('Colorado',
                'Lower Valley',
                'Silt',
                39.5713,
                -107.693,
                5620,
                '2015-05-08',
                today,
                'Full')
stg01 = Station('Kansas',
                'North Plains',
                'Sterling',
                40.4632,
                -103.028,
                4472,
                '2006-03-24',
                today,
                'Dry')
stn01 = Station('Kansas',
                'South Plains',
                'Stratton',
                39.2987,
                -102.5220,
                4321,
                '2006-04-02',
                today,
                'Dry')
twc01 = Station('Colorado',
                'Four Corners',
                'Towaoc',
                37.1891,
                -108.935,
                5319,
                '1998-06-30',
                today,
                'Partial')
wcf01 = Station('Arkansas',
                'Mesas',
                'Westcliffe',
                38.1504,
                -105.499,
                7734,
                '2010-09-20',
                today,
                'Full')
wfd01 = Station('Colorado',
                'Headwaters',
                'Wolford Mtn Reservoir',
                40.1387,
                -106.415,
                7520,
                '2004-11-30',
                today,
                'Dry')
wls01 = Station('Arkansas',
                'Plateau South of Valley',
                'Walsh',
                37.383,
                -102.294,
                3974,
                '2012-04-11',
                today,
                'Dry')
wry02 = Station('Kansas',
                'North Plains',
                'Wray 2',
                40.2187,
                -102.265,
                3736,
                '2015-04-01',
                today,
                'Full')
yjk01 = Station('Colorado',
                'Four Corners',
                'Yellow Jacket',
                37.5428,
                -108.74,
                6900,
                '1992-01-02',
                today,
                'Full')
yuc01 = Station('Colorado',
                'Four Corners',
                'Yucca House',
                37.2478,
                -108.6870,
                5975,
                '2002-08-23',
                today,
                'Dry')
yum02 = Station('Kansas',
                'North Plains',
                'Yuma',
                40.1504,
                -102.7240,
                4104,
                '1996-05-08',
                today,
                'Full')
